# %%
import atoti as tt

session = tt.create_session()
# Out:
# Welcome to atoti 0.5.1!
#
# By using this community edition, you agree with the license available at https://www.atoti.io/eula.
# Browse the official documentation at https://docs.atoti.io.
# Join the community at https://www.atoti.io/register.
#
# You can hide this message by setting the ATOTI_HIDE_EULA_MESSAGE environment variable to True.

# %%
countries_store = session.read_csv("data/countries.csv", keys=["Three_Letter_Country_Code"])

# %%
countries_store.head()
# Out:
#                           Continent_Name Continent_Code  \
# Three_Letter_Country_Code
# AFG                                 Asia             AS
# ALB                               Europe             EU
# ATA                           Antarctica             AN
# DZA                               Africa             AF
# ASM                              Oceania             OC
#
#                                                            Country_Name  \
# Three_Letter_Country_Code
# AFG                                    Afghanistan, Islamic Republic of
# ALB                                                Albania, Republic of
# ATA                        Antarctica (the territory South of 60 deg S)
# DZA                            Algeria, People's Democratic Republic of
# ASM                                                      American Samoa
#
#                           Two_Letter_Country_Code  Country_Number
# Three_Letter_Country_Code
# AFG                                            AF               4
# ALB                                            AL               8
# ATA                                            AQ              10
# DZA                                            DZ              12
# ASM                                            AS              16

# %%
flags_store = session.read_csv("data/flags.csv", keys=["Flag Code"])

# %%
flags_store.head()
# Out:
#                    Flag Name
# Flag Code
# E            Estimated value
# B                      Break
# I            Incomplete data
# n          National estimate

# %%
variables_store = session.read_csv("data/variables.csv", keys=["Variable Code"])

# %%
variables_store.head()
# Out:
#                                                    Variable Name Unit Code
# Variable Code
# CO2_PBPROD     Production-based CO2 productivity, GDP per uni...    USD_KG
# CO2_PBEMCAP    Production-based CO2 intensity, energy-related...     TONNE
# NRG_PROD              Energy productivity,  GDP per unit of TPES       USD
# NRG_INT                        Energy intensity, TPES per capita       TOE
# RE_TPES           Renewable energy supply, % total energy supply        PC

# %%
main_store = session.read_csv("data/green-growth.csv", keys=["Country Code", "Year"])

# %%
main_store.head()
# Out:
#                   Flag Codes  \
# Country Code Year
# NRU          2017        N/A
# AGO          2019        N/A
# NRU          1990        N/A
#              1995        N/A
#              2000        N/A
#
#                    Production-based CO2 productivity, GDP per unit of energy-related CO2 emissions (US dollars per kilogram)  \
# Country Code Year
# NRU          2017                                                NaN
# AGO          2019                                                NaN
# NRU          1990                                                NaN
#              1995                                                NaN
#              2000                                                NaN
#
#                    Production-based CO2 intensity, energy-related CO2 per capita (Tonnes)  \
# Country Code Year
# NRU          2017                                                NaN
# AGO          2019                                                NaN
# NRU          1990                                                NaN
#              1995                                                NaN
#              2000                                                NaN
#
#                    Energy productivity,  GDP per unit of TPES (US Dollar)  \
# Country Code Year
# NRU          2017                                                NaN
# AGO          2019                                                NaN
# NRU          1990                                                NaN
#              1995                                                NaN
#              2000                                                NaN
#
#                    Energy intensity, TPES per capita (Tonnes of oil equivalent (toe))  \
# Country Code Year
# NRU          2017                                                NaN
# AGO          2019                                                NaN
# NRU          1990                                                NaN
#              1995                                                NaN
#              2000                                                NaN
#
#                    Renewable energy supply, % total energy supply (Percentage)  \
# Country Code Year
# NRU          2017                                                NaN
# AGO          2019                                                NaN
# NRU          1990                                                NaN
#              1995                                                NaN
#              2000                                                NaN
#
#                    Renewable electricity, % total electricity generation (Percentage)  \
# Country Code Year
# NRU          2017                                                NaN
# AGO          2019                                                NaN
# NRU          1990                                                NaN
#              1995                                                NaN
#              2000                                                NaN
#
#                    Total freshwater abstraction per capita (Cubic metres per capita)  \
# Country Code Year
# NRU          2017                                                NaN
# AGO          2019                                                NaN
# NRU          1990                                                NaN
#              1995                                                NaN
#              2000                                                NaN
#
#                    Water stress, total freshwater abstraction as % total available renewable resources (Percentage)  \
# Country Code Year
# NRU          2017                                                NaN
# AGO          2019                                                NaN
# NRU          1990                                                NaN
#              1995                                                NaN
#              2000                                                NaN
#
#                    Water stress, total freshwater abstraction as % total internal renewable resources (Percentage)  \
# Country Code Year
# NRU          2017                                                NaN
# AGO          2019                                                NaN
# NRU          1990                                                NaN
#              1995                                                NaN
#              2000                                                NaN
#
#                    ...  \
# Country Code Year  ...
# NRU          2017  ...
# AGO          2019  ...
# NRU          1990  ...
#              1995  ...
#              2000  ...
#
#                    Emissions priced above EUR 30 per tonne of CO2, % total emissions (Percentage)  \
# Country Code Year
# NRU          2017                                                NaN
# AGO          2019                                                NaN
# NRU          1990                                                NaN
#              1995                                                NaN
#              2000                                                NaN
#
#                    Farmland Birds Index, 2000=100 (Index)  \
# Country Code Year
# NRU          2017                                     NaN
# AGO          2019                                     NaN
# NRU          1990                                     NaN
#              1995                                     NaN
#              2000                                     NaN
#
#                    Marine protected area, % total exclusive economic zone (Percentage)  \
# Country Code Year
# NRU          2017                                                NaN
# AGO          2019                                                NaN
# NRU          1990                                                NaN
#              1995                                                NaN
#              2000                                                NaN
#
#                    Intact forest landscape loss, % since 2000 (Percentage)  \
# Country Code Year
# NRU          2017                                                NaN
# AGO          2019                                                NaN
# NRU          1990                                                NaN
#              1995                                                NaN
#              2000                                                NaN
#
#                    Forest Birds Index, 2000=100 (Index)  \
# Country Code Year
# NRU          2017                                   NaN
# AGO          2019                                   NaN
# NRU          1990                                   NaN
#              1995                                   NaN
#              2000                                   NaN
#
#                    Electricity support, % total fossil fuel support (Percentage)  \
# Country Code Year
# NRU          2017                                                NaN
# AGO          2019                                                NaN
# NRU          1990                                                NaN
#              1995                                                NaN
#              2000                                                NaN
#
#                    CO2 intensity of GDP, CO2 emissions per unit of GDP ()  \
# Country Code Year
# NRU          2017                                                NaN
# AGO          2019                                                NaN
# NRU          1990                                                NaN
#              1995                                                NaN
#              2000                                                NaN
#
#                    Renewable energy supply (excluding solid biofuels), % total energy supply ()  \
# Country Code Year
# NRU          2017                                                NaN
# AGO          2019                                                NaN
# NRU          1990                                                NaN
#              1995                                                NaN
#              2000                                                NaN
#
#                    Naturally regenerating forests, % total forest area ()  \
# Country Code Year
# NRU          2017                                                NaN
# AGO          2019                                                NaN
# NRU          1990                                                NaN
#              1995                                                NaN
#              2000                                                NaN
#
#                    Forests with long-term management plans, % total forest area ()
# Country Code Year
# NRU          2017                                                NaN
# AGO          2019                                                NaN
# NRU          1990                                                NaN
#              1995                                                NaN
#              2000                                                NaN
#
# [5 rows x 155 columns]

# %%
main_store.join(countries_store, mapping={"Country Code": "Three_Letter_Country_Code"})

# %%
cube = session.create_cube(main_store)

# %%
h = cube.hierarchies
lvl = cube.levels
m = cube.measures

# %%
h
# Out:
# Hierarchies()

# %%
h["Country"] = [lvl["Continent_Name"], lvl["Country_Name"]]

# %%
del h["Two_Letter_Country_Code"]

# %%
del h["Country Code"]

# %%
del h["Continent_Name"]

# %%
del h["Continent_Code"]

# %%
del h["Country_Number"]

# %%
del h["Country_Name"]

# %%
summableMeasures = [
    "Total primary energy supply (tonne of oil equivalent)",
    "Production-based CO2 emissions (tonne)",
    "Demand-based CO2 emissions (tonne)",
    "Forest resource stocks (m3)",
    "Population",
    "Net migration"
]

# %%
for key in m:
    if "%" in key:
        m[key].formatter = "DOUBLE[#.##%]"
    isSummable = any(key.startswith(x) for x in summableMeasures)
    if ((isSummable and key.endswith(".MEAN")) or (not isSummable and key.endswith(".SUM"))):
        del m[key]

# %%
h["Year"].slicing = True

# %%
session.url
# Out:
# 'http://localhost:59865'
